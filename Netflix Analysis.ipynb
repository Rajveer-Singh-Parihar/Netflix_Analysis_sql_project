# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv(r"C:\Users\rajve\Downloads\NFLX.csv")

# %%
print(df.head())
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5044.000000  5044.000000  5044.000000  5044.000000  5044.000000
# mean    116.467981   118.237392   114.578719   116.456338   116.456338
# std     168.740876   171.140864   166.119837   168.668232   168.668232
# min       0.377857     0.410714     0.346429     0.372857     0.372857
# 25%       3.955357     4.031072     3.885357     3.958571     3.958571
# 50%      25.819285    26.342143    25.455000    25.802856    25.802856
# 75%     155.762497   157.654998   153.944996   155.869999   155.869999
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  5.044000e+03
# mean   1.653068e+07
# std    1.924487e+07
# min    2.856000e+05
# 25%    6.168225e+06
# 50%    1.059135e+07
# 75%    1.986552e+07
# max    3.234140e+08

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info
# Out:
# <bound method DataFrame.info of             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
# ...

# %%
df.dropna()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#          Volume
# 0     104790000
# ...

# %%
df.fillna(0)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#          Volume
# 0     104790000
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#          Volume
# 0     104790000
# ...

# %%
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
#         Volume
# 5039   8586000
# 5040  11398500
# 5041   8416200
# 5042   9623100
# 5043   7181700

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 5039  2022-05-27  193.190002  195.250000  190.369995  195.190002  195.190002
# 5040  2022-05-31  196.179993  199.949997  190.800003  197.440002  197.440002
# 5041  2022-06-01  198.699997  202.740005  191.660004  192.910004  192.910004
# 5042  2022-06-02  192.020004  205.470001  191.720001  205.089996  205.089996
# 5043  2022-06-03  200.139999  202.949997  198.050003  198.979996  198.979996
#
# ...

# %%
sns.lineplot(x=df.index,y=df['Volume'],label="Volume")
plt.title("Volume of stock versus time")
plt.show()

# %%
# High -Open-Close
df.plot(y=['High','Close','Open'],title="Netflix Stock Price")
plt.show()

# %%
# Highest Stock Price
a = df.sort_values(by='High',ascending=False).head(5)
print(a)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 4907  2021-11-17  690.000000  700.989990  686.090027  691.690002  691.690002
# 4909  2021-11-19  692.349976  694.159973  675.000000  678.799988  678.799988
# 4908  2021-11-18  691.609985  691.739990  679.739990  682.020020  682.020020
# 4894  2021-10-29  673.059998  690.969971  671.239990  690.309998  690.309998
# 4895  2021-11-01  689.059998  689.969971  676.539978  681.169983  681.169983
#
#        Volume
# 4907  2732800
# 4909  2613700
# 4908  2012900
# 4894  3825300
# 4895  3110900

# %%
# low stocks price
b = df.sort_values(by='Low',ascending=True).head(5)
print(b)
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume
# 97   2002-10-10  0.377857  0.525000  0.346429  0.506429   0.506429  13577200
# 96   2002-10-09  0.410000  0.410714  0.347143  0.372857   0.372857   5982200
# 94   2002-10-07  0.450000  0.458571  0.382143  0.412143   0.412143  15724800
# 95   2002-10-08  0.410714  0.427857  0.390714  0.405000   0.405000   4531800
# 101  2002-10-16  0.529286  0.532857  0.442857  0.459286   0.459286   5800200

# %%
# Plotting graph for high and low
fig,axes = plt.subplots(nrows=1,ncols=2,sharex=True,figsize=(12,5))
fig.suptitle("High and Low Values Stock Per Period Of Time",fontsize=18)
sns.lineplot(ax=axes[0],y=df["High"],x=df.index,color='green')
sns.lineplot(ax=axes[1],y=df["Low"],x=df.index,color='red')
plt.show()

# %%
# Distribution of volumes
sns.set_theme()
plt.figure(figsize=(7,3))
sns.kdeplot(df['Volume']/1e6, fill=True, color='royalblue')
plt.xlabel('Daily Volume (millions)')
plt.title('Distribution of Volume (seaborn KDE)')
plt.show()
